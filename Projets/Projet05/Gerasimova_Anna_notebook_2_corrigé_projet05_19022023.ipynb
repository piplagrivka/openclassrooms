# %% [markdown]
# Projet 5: **Optimiser la gestion des données d'une boutique avec R ou Python**
#
# Mission:
# 1. rapprocher 2 tableaux (ERP et CRM)
# 2. trouver le chiffre d’affaires par produit et le total du chiffre d’affaires réalisé en ligne
# 3. analyser la variable "prix"

# %% [markdown]
# **Importation de données et l'analyse par .describe(), .info(), et .shape()**

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import os

# %%
working_directory= '/content/gdrive/MyDrive/Colab Notebooks/OC_projet05'

# %%
os.path.join(working_directory, 'web.xlsx')
# Out:
# '/content/gdrive/MyDrive/Colab Notebooks/OC_projet05/web.xlsx'

# %%
crm= pd.read_excel(os.path.join(working_directory, 'web.xlsx'))
pd.set_option('display.max_columns', None)
display(crm)
# Out:
# /usr/local/lib/python3.9/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                       sku  virtual  downloadable  rating_count  \
# 0     bon-cadeau-25-euros        0             0             0
# 1                   15298        0             0             0
# 2                   15296        0             0             0
# 3                   15300        0             0             0
# 4                   19814        0             0             0
# ...                   ...      ...           ...           ...
# 1508                16135        0             0             0
# 1509                15891        0             0             0
# 1510                15887        0             0             0
# 1511              13127-1        0             0             0
# 1512                16230        0             0             0
#
# ...

# %%
crm.shape
# Out:
# (1513, 28)

# %%
crm.describe()
# Out:
#        virtual  downloadable  rating_count  average_rating  total_sales  \
# count   1513.0        1513.0        1513.0          1430.0  1430.000000
# mean       0.0           0.0           0.0             0.0     4.006993
# std        0.0           0.0           0.0             0.0     8.510559
# min        0.0           0.0           0.0             0.0     0.000000
# 25%        0.0           0.0           0.0             0.0     0.000000
# 50%        0.0           0.0           0.0             0.0     1.000000
# 75%        0.0           0.0           0.0             0.0     4.000000
# max        0.0           0.0           0.0             0.0    96.000000
#
#        tax_class  post_author  post_content  post_password  \
# count        0.0  1430.000000           0.0            0.0
# mean         NaN     1.998601           NaN            NaN
# std          NaN     0.037385           NaN            NaN
# min          NaN     1.000000           NaN            NaN
# ...

# %%
crm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1513 entries, 0 to 1512
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sku                    1428 non-null   object
#  1   virtual                1513 non-null   int64
#  2   downloadable           1513 non-null   int64
#  3   rating_count           1513 non-null   int64
#  4   average_rating         1430 non-null   float64
#  5   total_sales            1430 non-null   float64
#  6   tax_status             716 non-null    object
#  7   tax_class              0 non-null      float64
#  8   post_author            1430 non-null   float64
#  9   post_date              1430 non-null   datetime64[ns]
#  10  post_date_gmt          1430 non-null   datetime64[ns]
#  11  post_content           0 non-null      float64
#  12  post_title             1430 non-null   object
#  13  post_excerpt           716 non-null    object
# ...

# %%
crm.nunique()
# Out:
# sku                       714
# virtual                     1
# downloadable                1
# rating_count                1
# average_rating              1
# total_sales                41
# tax_status                  1
# tax_class                   0
# post_author                 2
# post_date                 716
# post_date_gmt             716
# post_content                0
# post_title                713
# post_excerpt              679
# post_status                 1
# comment_status              1
# ping_status                 1
# post_password               0
# post_name                 716
# post_modified             589
# post_modified_gmt         589
# post_content_filtered       0
# post_parent                 1
# guid                     1430
# menu_order                  1
# post_type                   2
# post_mime_type              1
# comment_count               1
# dtype: int64

# %%
erp= pd.read_excel(os.path.join(working_directory, 'erp.xlsx'))
display(erp)
# Out:
# /usr/local/lib/python3.9/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#      product_id  onsale_web  price  stock_quantity stock_status
# 0          3847           1   24.2               0   outofstock
# 1          3849           1   34.3               0   outofstock
# 2          3850           1   20.8               0   outofstock
# 3          4032           1   14.1               0   outofstock
# 4          4039           1   46.0               0   outofstock
# ..          ...         ...    ...             ...          ...
# 820        7203           0   45.0              30      instock
# 821        7204           0   45.0               9      instock
# 822        7247           1   54.8              23      instock
# 823        7329           0   26.5              14      instock
# 824        7338           1   16.3              45      instock
#
# [825 rows x 5 columns]

# %%
erp.shape
# Out:
# (825, 5)

# %%
erp.describe()
# Out:
#         product_id  onsale_web       price  stock_quantity
# count   825.000000  825.000000  825.000000      825.000000
# mean   5162.597576    0.869091   32.415636       26.496970
# std     902.644635    0.337506   26.795849       45.892422
# min    3847.000000    0.000000    5.200000        0.000000
# 25%    4348.000000    1.000000   14.600000        1.000000
# 50%    4907.000000    1.000000   24.400000       11.000000
# 75%    5805.000000    1.000000   42.000000       34.000000
# max    7338.000000    1.000000  225.000000      578.000000

# %%
erp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      825 non-null    int64
#  1   onsale_web      825 non-null    int64
#  2   price           825 non-null    float64
#  3   stock_quantity  825 non-null    int64
#  4   stock_status    825 non-null    object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 32.4+ KB

# %%
liaison= pd.read_excel(os.path.join(working_directory, 'liaison.xlsx'))
display(liaison)
# Out:
# /usr/local/lib/python3.9/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#      product_id   id_web
# 0          3847    15298
# 1          3849    15296
# 2          3850    15300
# 3          4032    19814
# 4          4039    19815
# ..          ...      ...
# 820        7203      NaN
# 821        7204      NaN
# 822        7247  13127-1
# 823        7329  14680-1
# 824        7338    16230
#
# [825 rows x 2 columns]

# %%
liaison.shape
# Out:
# (825, 2)

# %%
liaison.describe()
# Out:
#         product_id
# count   825.000000
# mean   5162.597576
# std     902.644635
# min    3847.000000
# 25%    4348.000000
# 50%    4907.000000
# 75%    5805.000000
# max    7338.000000

# %%
liaison.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 825 entries, 0 to 824
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   product_id  825 non-null    int64
#  1   id_web      734 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 13.0+ KB

# %%
liaison.loc[(liaison['id_web'].isna()==True)]
# Out:
#      product_id id_web
# 19         4055    NaN
# 49         4090    NaN
# 50         4092    NaN
# 119        4195    NaN
# 131        4209    NaN
# ..          ...    ...
# 817        7196    NaN
# 818        7200    NaN
# 819        7201    NaN
# 820        7203    NaN
# 821        7204    NaN
#
# [91 rows x 2 columns]

# %% [markdown]
# Renommer la colonne 'sku' du tableau crm par 'id_web'

# %%
crm.rename(columns={'sku': 'id_web'}, inplace=True)

# %% [markdown]
# **Tester les clés primaires et nettoyage des données**

# %%
def testerCle(df, colonnes):
    """Fonction qui prend en arguments un dataframe et les colonnes qui composent la clé primaire à tester."""

    # On compare la taille du dataframe avant et après dédoublonnage 
    if df.size == df.drop_duplicates(colonnes).size :
        print("La clé n'est pas présente plusieurs fois dans le dataframe.")
        print("Elle peut donc être utilisée comme clé primaire.")
    else :
        print("La clé est présente plusieurs fois dans le dataframe.")
        print("Elle ne peut donc pas être utilisée comme clé primaire.")
    
    # On renvoie également le comptage
    print("Le dataframe est de la forme : " + str(df.shape) + " (lignes, colonnes)", '\n','\n')

# %%
testerCle(crm, ['id_web'])
testerCle(crm, ['id_web','post_type'])
# Out:
# La clé est présente plusieurs fois dans le dataframe.
# Elle ne peut donc pas être utilisée comme clé primaire.
# Le dataframe est de la forme : (1513, 28) (lignes, colonnes)
#
#
# La clé est présente plusieurs fois dans le dataframe.
# Elle ne peut donc pas être utilisée comme clé primaire.
# Le dataframe est de la forme : (1513, 28) (lignes, colonnes)

# %%
crm.isna().any()
# Out:
# id_web                    True
# virtual                  False
# downloadable             False
# rating_count             False
# average_rating            True
# total_sales               True
# tax_status                True
# tax_class                 True
# post_author               True
# post_date                 True
# post_date_gmt             True
# post_content              True
# post_title                True
# post_excerpt              True
# post_status               True
# comment_status            True
# ping_status               True
# post_password             True
# post_name                 True
# post_modified             True
# post_modified_gmt         True
# post_content_filtered     True
# post_parent               True
# guid                      True
# menu_order                True
# post_type                 True
# post_mime_type            True
# comment_count             True
# dtype: bool

# %%
import missingno as msno
msno.matrix(crm)
# Out:
# <Axes: >

# %%
crm.loc[(crm['id_web'].isna()==True)]
# Out:
#     id_web  virtual  downloadable  rating_count  average_rating  total_sales  \
# 178    NaN        0             0             0             NaN          NaN
# 179    NaN        0             0             0             NaN          NaN
# 227    NaN        0             0             0             NaN          NaN
# 230    NaN        0             0             0             NaN          NaN
# 231    NaN        0             0             0             NaN          NaN
# ..     ...      ...           ...           ...             ...          ...
# 792    NaN        0             0             0             NaN          NaN
# 793    NaN        0             0             0             NaN          NaN
# 794    NaN        0             0             0             NaN          NaN
# 795    NaN        0             0             0             NaN          NaN
# 796    NaN        0             0             0             NaN          NaN
#
# ...

# %%
display(crm.loc[(crm['id_web'].isna()==True)&(crm['total_sales'].isna()!=True)])
# Out:
#     id_web  virtual  downloadable  rating_count  average_rating  total_sales  \
# 470    NaN        0             0             0             0.0          0.0
# 471    NaN        0             0             0             0.0          0.0
#
#     tax_status  tax_class  post_author           post_date  \
# 470    taxable        NaN          2.0 2018-07-31 12:07:23
# 471    taxable        NaN          2.0 2018-08-08 11:23:43
#
#           post_date_gmt  post_content  \
# 470 2018-07-31 10:07:23           NaN
# 471 2018-08-08 09:23:43           NaN
#
#                                           post_title  \
# 470       Pierre Jean Villa Côte Rôtie Fongeant 2017
# 471  Pierre Jean Villa Condrieu Jardin Suspendu 2018
#
#                                           post_excerpt post_status  \
# 470  Fongeant 2017 explose sur un fruit brillant, p...     publish
# 471  <span id="u1194-83">Le nez séduit par ses parf...     publish
#
#     comment_status ping_status  post_password  \
# ...

# %%
clear_crm=crm.dropna(subset=['id_web'])
testerCle(clear_crm, ['id_web'])
# Out:
# La clé est présente plusieurs fois dans le dataframe.
# Elle ne peut donc pas être utilisée comme clé primaire.
# Le dataframe est de la forme : (1428, 28) (lignes, colonnes)

# %%
print(clear_crm.duplicated('id_web').sum())
duplicate= clear_crm[clear_crm.duplicated('id_web', keep='last')]
display(duplicate)
# Out:
# 714
#                   id_web  virtual  downloadable  rating_count  average_rating  \
# 0    bon-cadeau-25-euros        0             0             0             0.0
# 1                  15298        0             0             0             0.0
# 2                  15296        0             0             0             0.0
# 3                  15300        0             0             0             0.0
# 4                  19814        0             0             0             0.0
# ..                   ...      ...           ...           ...             ...
# 762                16135        0             0             0             0.0
# 767                15891        0             0             0             0.0
# 768                15887        0             0             0             0.0
# 797              13127-1        0             0             0             0.0
# 798                16230        0             0             0             0.0
#
# ...

# %%
clear_crm.loc[clear_crm['id_web']=='bon-cadeau-25-euros']
# Out:
#                    id_web  virtual  downloadable  rating_count  \
# 0     bon-cadeau-25-euros        0             0             0
# 1209  bon-cadeau-25-euros        0             0             0
#
#       average_rating  total_sales tax_status  tax_class  post_author  \
# 0                0.0         10.0    taxable        NaN          1.0
# 1209             0.0         10.0        NaN        NaN          1.0
#
#                post_date       post_date_gmt  post_content         post_title  \
# 0    2018-06-01 13:53:46 2018-06-01 11:53:46           NaN  Bon cadeau de 25€
# 1209 2018-06-01 13:53:46 2018-06-01 11:53:46           NaN  Bon cadeau de 25€
#
#                                            post_excerpt post_status  \
# 0     <span style="color: #a85253;"><strong>Parlons ...     publish
# 1209                                                NaN     publish
#
#      comment_status ping_status  post_password               post_name  \
# ...

# %%
clear_crm.loc[clear_crm['post_type']=='product']
# Out:
#                   id_web  virtual  downloadable  rating_count  average_rating  \
# 0    bon-cadeau-25-euros        0             0             0             0.0
# 1                  15298        0             0             0             0.0
# 2                  15296        0             0             0             0.0
# 3                  15300        0             0             0             0.0
# 4                  19814        0             0             0             0.0
# ..                   ...      ...           ...           ...             ...
# 762                16135        0             0             0             0.0
# 767                15891        0             0             0             0.0
# 768                15887        0             0             0             0.0
# 797              13127-1        0             0             0             0.0
# 798                16230        0             0             0             0.0
#
# ...

# %%
testerCle(clear_crm, ['id_web','post_type'])
# Out:
# La clé n'est pas présente plusieurs fois dans le dataframe.
# Elle peut donc être utilisée comme clé primaire.
# Le dataframe est de la forme : (1428, 28) (lignes, colonnes)

# %%
clear_crm=clear_crm.loc[clear_crm['post_type']=='product']
testerCle(clear_crm, ['id_web'])
# Out:
# La clé n'est pas présente plusieurs fois dans le dataframe.
# Elle peut donc être utilisée comme clé primaire.
# Le dataframe est de la forme : (714, 28) (lignes, colonnes)

# %%
testerCle(erp, 'product_id')
# Out:
# La clé n'est pas présente plusieurs fois dans le dataframe.
# Elle peut donc être utilisée comme clé primaire.
# Le dataframe est de la forme : (825, 5) (lignes, colonnes)

# %% [markdown]
# **Vérification de la jointure**

# %%
data1= pd.merge(erp, liaison, on='product_id', indicator=True, how='outer')
display(data1)
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status   id_web  \
# 0          3847           1   24.2               0   outofstock    15298
# 1          3849           1   34.3               0   outofstock    15296
# 2          3850           1   20.8               0   outofstock    15300
# 3          4032           1   14.1               0   outofstock    19814
# 4          4039           1   46.0               0   outofstock    19815
# ..          ...         ...    ...             ...          ...      ...
# 820        7203           0   45.0              30      instock      NaN
# 821        7204           0   45.0               9      instock      NaN
# 822        7247           1   54.8              23      instock  13127-1
# 823        7329           0   26.5              14      instock  14680-1
# 824        7338           1   16.3              45      instock    16230
#
#     _merge
# 0     both
# 1     both
# 2     both
# 3     both
# 4     both
# ..     ...
# ...

# %%
data1.loc[data1['_merge']!='both']
# Out:
# Empty DataFrame
# Columns: [product_id, onsale_web, price, stock_quantity, stock_status, id_web, _merge]
# Index: []

# %%
data1=data1.drop(columns='_merge')

# %%
data= pd.merge(data1, clear_crm, on='id_web', indicator=True, how='outer')
#display(data)
print(data['_merge'].value_counts())
# Out:
# both          714
# left_only     111
# right_only      0
# Name: _merge, dtype: int64

# %%
columns= ['product_id','onsale_web','price','stock_quantity','id_web','total_sales','post_title']
display(data[columns].head(10))
# Out:
#    product_id  onsale_web  price  stock_quantity id_web  total_sales  \
# 0        3847           1   24.2               0  15298          6.0
# 1        3849           1   34.3               0  15296          0.0
# 2        3850           1   20.8               0  15300          0.0
# 3        4032           1   14.1               0  19814          3.0
# 4        4039           1   46.0               0  19815          0.0
# 5        4040           1   34.3               0  15303          0.0
# 6        4041           1   32.7              15  14975          0.0
# 7        4042           1   31.2              34  16042          7.0
# 8        4043           1   60.0              12  14980          3.0
# 9        4045           1   42.6              66  16041         14.0
#
#                                           post_title
# 0        Pierre Jean Villa Saint-Joseph Préface 2018
# 1    Pierre Jean Villa Saint-Joseph Rouge Tildé 2017
# ...

# %% [markdown]
# **Chiffre d'affaire par produit**

# %%
data['CA_produit']= (data['price']*data['total_sales'])
display(data[['product_id','post_title','price','total_sales','CA_produit']].sort_values(by=['CA_produit'],ascending=False, na_position='last').head(20))
# Out:
#      product_id                                         post_title  price  \
# 286        4334             Champagne Gosset Grand Blanc de Blancs   49.0
# 162        4144                        Champagne Gosset Grand Rosé   49.0
# 310        4402                               Cognac Frapin VIP XO  176.0
# 161        4142              Champagne Gosset Grand Millésime 2006   53.0
# 160        4141                    Champagne Gosset Grande Réserve   39.0
# 293        4355     Champagne Egly-Ouriet Grand Cru Blanc de Noirs  126.5
# 291        4352     Champagne Egly-Ouriet Grand Cru Millésimé 2008  225.0
# 170        4153   Elian Daros Côtes du Marmandais Clos Baquey 2015   29.0
# 761        6206           Domaine Giudicelli Patrimonio Blanc 2019   25.2
# 121        4068  Gilles Robin Crozes-Hermitage Rouge Papillon 2019   16.6
# 17         4053       Clos du Mont-Olivet Châteauneuf-du-Pape 2012   44.3
# 322        4596  Marc Colin Et Fils Chassagne-Montrachet Blanc ...   43.9
# ...

# %% [markdown]
# Chiffre d'affaire total
# hypothèse 1: les bons cadeau n'ont pas été utilisés.

# %%
CA_total=data['CA_produit'].sum()
print('Le chiffre d\'affaire 1:', CA_total, 'euros')
# Out:
# Le chiffre d'affaire 1: 70568.6 euros

# %% [markdown]
# Chiffre d'affaire total
# hypothèse 2: les bons cadeau ont été utilisés.

# %%
data2=data[data['id_web'] !='bon-cadeau-25-euros']
CA_total2 = data2['CA_produit'].sum()
print('Le chiffre d\'affaire 2:', CA_total2, 'euros')
# Out:
# Le chiffre d'affaire 2: 70318.6 euros

# %% [markdown]
# **Erreurs dans la série des prix**

# %%
import matplotlib.pyplot as plt

data["price"].hist(density=True,bins=50)
plt.show()
data['price'].describe()
# Out:
# count    825.000000
# mean      32.415636
# std       26.795849
# min        5.200000
# 25%       14.600000
# 50%       24.400000
# 75%       42.000000
# max      225.000000
# Name: price, dtype: float64

# %%
data['price'].mode()
# Out:
# 0    45.0
# Name: price, dtype: float64

# %%
# if x>Q3+1.5Q1Q3 ==> outlier
plt.figure(figsize=(14, 7))
data.boxplot(column="price", vert=False)
plt.title("Repartition des prix")
plt.xlabel('prix')     
plt.show()

# %%
#data.boxplot?

# %%
_, bp= pd.DataFrame.boxplot(data['price'], return_type='both')
outliers= [flier.get_ydata() for flier in bp["fliers"]]
print('Outliers:', outliers)
# Out:
# Outliers: [array([86.1, 144.0, 84.7, 92.0, 100.0, 88.4, 225.0, 126.5, 85.6, 176.0,
#        108.5, 157.0, 104.0, 109.6, 102.3, 137.0, 217.5, 105.0, 105.0,
#        112.0, 86.8, 92.0, 83.7, 124.8, 175.0, 191.3, 93.0, 122.0, 114.0,
#        135.0, 105.6, 116.4, 115.0, 121.0, 99.0, 115.0, 121.0],
#       dtype=object)]

# %%
k= min(min(outliers))
print(k)
print('Nombre des outliers selon le boxplot:',len(data.loc[data['price']>= k]))
data_prix_web= data.loc[data['price']>83.1, ['price','post_title']].sort_values(by='price', ascending=False).head(10)
data_prix_web['prix_web']=[830,174,138,180,175,175,0,120,169,0]
display(data_prix_web)
# Out:
# 83.7
# Nombre des outliers selon le boxplot: 37
#      price                                         post_title  prix_web
# 291  225.0     Champagne Egly-Ouriet Grand Cru Millésimé 2008       830
# 525  217.5     David Duband Charmes-Chambertin Grand Cru 2014       174
# 692  191.3  Coteaux Champenois Egly-Ouriet Ambonnay Rouge ...       138
# 310  176.0                               Cognac Frapin VIP XO       180
# 657  175.0                Camille Giroud Clos de Vougeot 2016       175
# 313  157.0  Cognac Frapin Château de Fontpinot 1989 20 Ans...       175
# 30   144.0                                                NaN         0
# 478  137.0  Domaine Des Croix Corton Charlemagne Grand Cru...       120
# 752  135.0             Champagne Gosset Célébris Vintage 2007       169
# 293  126.5     Champagne Egly-Ouriet Grand Cru Blanc de Noirs         0

# %%
#Z score=(x-mean)/std if |zscore|>3 ==> outlier
import numpy as np

data['zscore']= (data['price']-np.mean(data['price']))/np.std(data['price'])
print('Nombre des outliers selon le Z-score:', len(data.loc[abs(data['zscore'])>2]))
# Out:
# Nombre des outliers selon le Z-score: 34

# %%
display(data[['product_id','post_title','price','total_sales','CA_produit']].sort_values(by=['total_sales'],ascending=False, na_position='last').head(20))
# Out:
#      product_id                                         post_title  price  \
# 286        4334             Champagne Gosset Grand Blanc de Blancs   49.0
# 162        4144                        Champagne Gosset Grand Rosé   49.0
# 121        4068  Gilles Robin Crozes-Hermitage Rouge Papillon 2019   16.6
# 210        4200  Moulin de Gassac IGP Pays d'Hérault Guilhem Ro...    5.8
# 188        4172                   Maurel Pays d'Oc Chardonnay 2019    5.7
# 200        4187  Le Pas de l'Escalette Languedoc Les Petits Pas...   13.3
# 761        6206           Domaine Giudicelli Patrimonio Blanc 2019   25.2
# 160        4141                    Champagne Gosset Grande Réserve   39.0
# 734        6047     Château de La Liquière Faugères L'Ampoule 2019   10.9
# 418        4729         Emile Boeckel Crémant Brut Blanc de Blancs    8.6
# 762        6207           Domaine Giudicelli Patrimonio Rouge 2016   25.2
# 170        4153   Elian Daros Côtes du Marmandais Clos Baquey 2015   29.0
# ...
